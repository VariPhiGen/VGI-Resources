# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.6 MB/s eta 0:00:00
# ...

# %%
# !pip install Pillow

# %%
from ultralytics import YOLO
from PIL import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !unzip "/content/ppe_dataset.zip"
# Out:
# Archive:  /content/ppe_dataset.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/00011_jpg.rf.aefcb5e1e3b400ec9ffeadc561a3dfba.jpg
#  extracting: test/images/00014_jpg.rf.1763dde0657fee9a5b15a7c6cfce855b.jpg
#  extracting: test/images/00014_jpg.rf.3c9224aad9816b5134832c7620770ac8.jpg
#  extracting: test/images/00014_jpg.rf.830b75a7210d58d30a1e61dfdd7860bf.jpg
#  extracting: test/images/00035_jpg.rf.1cd189c37ec6c92531a764df402032e7.jpg
#  extracting: test/images/00085_jpg.rf.b0f28607890afc49cef16171d647953f.jpg
#  extracting: test/images/00113_jpg.rf.2ed4189e4999e15cb975fad31f67fae2.jpg
#  extracting: test/images/00113_jpg.rf.364d5d91df69b482aa8c817217ad53ee.jpg
#  extracting: test/images/00119_jpg.rf.7d09825402210681f014496b730ef221.jpg
#  extracting: test/images/00121_jpg.rf.230ce1e240dcd843f3e85ced5e776456.jpg
# ...

# %%
# !pip install opencv-python

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.train(data="/content/data.yaml",epochs=10,imgsz=640)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.predict("/content/test/images/Aitin2331_jpg.rf.f0517ee8bb0bc9613f5747c7e561eb20.jpg")
# Out:
# image 1/1 /content/test/images/Aitin2331_jpg.rf.f0517ee8bb0bc9613f5747c7e561eb20.jpg: 640x640 3 Helmets, 7 Vests, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
result = results[0]

# %%
len(result)
# Out:
# 10

# %%
result.boxes.xyxy
# Out:
# tensor([[ 64.1963,  53.8527, 202.8370, 199.3626],
#         [346.4672,  78.7054, 459.4980, 247.0033],
#         [  0.0000, 214.6688, 160.0034, 638.3495],
#         [352.9433, 373.1155, 406.3836, 548.3109],
#         [257.7954, 477.1568, 314.1447, 614.9282],
#         [414.6689, 203.2554, 576.1324, 627.1626],
#         [240.5268, 363.4397, 320.9620, 621.2432],
#         [356.9979, 373.8914, 406.0562, 477.4562],
#         [192.7561, 465.1392, 247.5300, 611.5518],
#         [ 14.8539, 404.1463, 243.0244, 640.0000]], device='cuda:0')

# %%
result.plot()
# Out:
# array([[[250, 252, 252],
#         [252, 250, 250],
#         [245, 237, 238],
#         ...,
#         [ 67,  46,  49],
#         [ 67,  46,  49],
#         [ 68,  47,  50]],
#
#        [[252, 254, 254],
#         [254, 252, 252],
#         [248, 240, 241],
#         ...,
#         [ 67,  46,  49],
#         [ 67,  46,  49],
#         [ 68,  47,  50]],
#
#        [[253, 255, 255],
#         [255, 254, 254],
#         [252, 244, 245],
#         ...,
#         [ 67,  46,  49],
#         [ 67,  46,  49],
#         [ 68,  47,  50]],
#
#        ...,
#
#        [[183, 223,   0],
#         [183, 223,   0],
#         [183, 223,   0],
#         ...,
#         [ 75,  46,  39],
#         [ 76,  47,  40],
#         [ 77,  48,  41]],
#
#        [[183, 223,   0],
#         [183, 223,   0],
#         [183, 223,   0],
#         ...,
#         [ 75,  46,  39],
#         [ 76,  47,  40],
#         [ 77,  48,  41]],
#
#        [[183, 223,   0],
#         [183, 223,   0],
#         [183, 223,   0],
# ...

# %%
model.export(format="onnx")
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
#
# PyTorch: starting from '/content/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.78...
# ONNX: export success ✅ 1.2s, saved as '/content/runs/detect/train2/weights/best.onnx' (11.7 MB)
#
# Export complete (1.6s)
# Results saved to /content/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/train2/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/content/runs/detect/train2/weights/best.onnx imgsz=640 data=/content/data.yaml
# Visualize:       https://netron.app
# '/content/runs/detect/train2/weights/best.onnx'

# %%
## label dataset --> zip --> gpu accesable --> upload --> imports --> update the yaml file location --> model.train() --> ( best.pt , last.pt) --> export --> downloaded --> perform the inferencing part !!

# %%
# !pip install mlflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 91.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 111.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.9/753.9 kB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 27.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import settings

# Update a setting
settings.update({"mlflow": True})

# Reset settings to default values
settings.reset()

# %%
# !export MLFLOW_EXPERIMENT_NAME="Variphi-testing"

# %%
# !export MLFLOW_RUN="Variphi-testing-running"

# %%
# !mlflow server --backend-store-uri runs/mlflow
# Out:
# Registry store URI not provided. Using backend store URI.
# /usr/local/lib/python3.12/dist-packages/mlflow/server/handlers.py:259: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance.
#   return FileStore(store_uri, artifact_uri)
# /usr/local/lib/python3.12/dist-packages/mlflow/server/handlers.py:288: FutureWarning: The filesystem model registry backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance.
#   return FileStore(store_uri)
# ...
