# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.3/112.6 GB disk)

# %%
# !unzip "/content/yolo-seg.zip"
# Out:
# Archive:  /content/yolo-seg.zip
# caution: filename not matched:  -y

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n-pose.pt")

# %%
results = model.train(data="/content/data.yaml", epochs=10, imgsz=640)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil
shutil.make_archive('/content/runs', 'zip', '/content/runs')
# Out:
# '/content/runs.zip'

# %%
model_trained_100_epoch = YOLO("/content/best_pose.pt")

# %%
results = model_trained_100_epoch("/content/train/images/FallJump_29_11_24-1146-_jpg.rf.e20b5941fa20dfdaaf2f0a50f934f351.jpg")
# Out:
# image 1/1 /content/train/images/FallJump_29_11_24-1146-_jpg.rf.e20b5941fa20dfdaaf2f0a50f934f351.jpg: 640x384 1 walking, 67.6ms
# Speed: 2.6ms preprocess, 67.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)

# %%
len(results)
# Out:
# 1

# %%
results[0].plot()
# Out:
# array([[[235, 205, 188],
#         [234, 204, 187],
#         [232, 202, 185],
#         ...,
#         [240, 205, 185],
#         [240, 205, 185],
#         [240, 205, 185]],
#
#        [[234, 204, 187],
#         [233, 203, 186],
#         [232, 202, 185],
#         ...,
#         [240, 205, 185],
#         [240, 205, 185],
#         [240, 205, 185]],
#
#        [[233, 203, 186],
#         [233, 203, 186],
#         [233, 203, 186],
#         ...,
#         [240, 205, 185],
#         [240, 205, 185],
#         [240, 205, 185]],
#
#        ...,
#
#        [[ 40,  63,  85],
#         [ 38,  61,  83],
#         [ 39,  62,  84],
#         ...,
#         [ 67,  76,  96],
#         [ 68,  74,  93],
#         [ 66,  72,  91]],
#
#        [[ 41,  64,  86],
#         [ 41,  64,  86],
#         [ 42,  65,  87],
#         ...,
#         [ 69,  78,  98],
#         [ 72,  78,  97],
#         [ 69,  75,  94]],
#
#        [[ 44,  67,  89],
#         [ 45,  68,  90],
#         [ 47,  70,  92],
# ...

# %%
# !unzip "/content/variphi-segmentation.v1-version-1.yolov11.zip"
# Out:
# Archive:  /content/variphi-segmentation.v1-version-1.yolov11.zip
# replace README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
y
